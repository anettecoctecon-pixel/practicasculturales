# %%
var=2
while(var!=5):
  print("selecciona una opcino:/n 1-sumar/n 2-resta/n 3-multiplicacion/n 4-divicion/n 5-salir")
  var=input("")
  if(var=="1"):
    var1=int(input("dame un numero"))
    var2=int(input("dame otr numero"))
    print(var1+var2)
  elif(var=="2"):
    var1=int(input("dame un numero"))
    var2=int(input("dame otro numero"))
    print(var1-var2)
  elif(var=="3"):
    var1=int(input("dame un numero"))
    var2=int(input("dame otro numero"))
    print(var1*var2)
  elif(var=="4"):
    var1=int(input("dame un numero"))
    var2=int(input("dame otro numero"))
    print(var1/var2)
# Out:
# selecciona una opcino:/n 1-sumar/n 2-resta/n 3-multiplicacion/n 4-divicion/n 5-salir
# 1
# dame un numero5
# dame otr numero10
# 15
# selecciona una opcino:/n 1-sumar/n 2-resta/n 3-multiplicacion/n 4-divicion/n 5-salir
# 2
# dame un numero10
# dame otro numero8
# 2
# selecciona una opcino:/n 1-sumar/n 2-resta/n 3-multiplicacion/n 4-divicion/n 5-salir
# 3
# dame un numero10
# dame otro numero5
# 50
# selecciona una opcino:/n 1-sumar/n 2-resta/n 3-multiplicacion/n 4-divicion/n 5-salir
# 4
# dame un numero259
# dame otro numero27
# 9.592592592592593
# selecciona una opcino:/n 1-sumar/n 2-resta/n 3-multiplicacion/n 4-divicion/n 5-salir
